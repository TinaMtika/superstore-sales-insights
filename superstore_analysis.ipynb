# %%
# 📦 Step 1: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: Clean visuals
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# 📂 Step 2: Load the Data
df = pd.read_csv(r'C:\Users\Admin\Documents\superstore-sales-insights\Global_Superstore2.csv', encoding='latin1')
  # or utf-8 if that fails

# 👀 Step 3: Quick Look
print("Dataset shape:", df.shape)
df.head()

# 📋 Step 4: Basic Info
df.info()

# 🔍 Step 5: Check Missing Values
df.isnull().sum().sort_values(ascending=False)

# %%
print("Before removing duplicates:", df.shape)
df.drop_duplicates(inplace=True)
print("After removing duplicates:", df.shape)
# Out:
# Before removing duplicates: (51290, 24)
# After removing duplicates: (51290, 24)

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Postal Code    41296
# dtype: int64

# %%
df.dropna(subset=['City', 'Postal Code'], inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='Category', y='Sales', estimator=sum)
plt.title('Total Sales by Category')
# Out:
# Text(0.5, 1.0, 'Total Sales by Category')

# %%
top_cities = df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)
top_cities.plot(kind='bar', figsize=(12,6), title='Top 10 Cities by Sales')
# Out:
# <Axes: title={'center': 'Top 10 Cities by Sales'}, xlabel='City'>

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df, x='Region', y='Profit', estimator=sum)
plt.title('Total Profit by Region')
plt.xticks(rotation=45)
plt.show()
